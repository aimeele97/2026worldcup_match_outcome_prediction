# %% [markdown]
# <div style="max-width: 95%; width: 900px; margin: 0 auto; box-sizing: border-box; background: linear-gradient(135deg, #0a1628 0%, #1a3a5c 50%, #0d2137 100%); padding: 30px 35px; border-radius: 18px; font-family: 'Segoe UI', Arial, sans-serif; color: #ffffff; border: 1px solid #2a5a8a;">
#
# <div style="display: flex; flex-wrap: wrap; align-items: center; gap: 15px; margin-bottom: 8px;">
#   <span style="font-size: 48px;">🏆</span>
#   <div style="flex: 1; min-width: 200px;">
#     <p style="margin: 0; font-size: 11px; letter-spacing: 4px; text-transform: uppercase; color: #7ab8e8; font-weight: 600;">FIFA</p>
#     <h1 style="margin: 0; font-size: 32px; font-weight: 800; letter-spacing: 1px; background: linear-gradient(90deg, #ffffff, #7ab8e8); -webkit-background-clip: text; -webkit-text-fill-color: transparent;">World Cup 2026</h1>
#     <p style="margin: 0; font-size: 13px; letter-spacing: 6px; text-transform: uppercase; color: #f0a500; font-weight: 700;">Winner Prediction</p>
#   </div>
# </div>
#
# </div>

# %% [markdown]
# <div style="max-width: 95%; width: 900px; margin: 0 auto; box-sizing: border-box; padding: 5% 4%; border-radius: 15px; background-color: #f8f9fa; border-left: 8px solid #2e7d32; box-shadow: 0 4px 6px rgba(0,0,0,0.05); font-family: 'Segoe UI', Helvetica, Arial, sans-serif;">
#     <div style="text-align: center; margin-bottom: 30px;">
#         <h1 style="color: #1b5e20; font-size: 2.5em; font-weight: 700; margin-bottom: 5px; letter-spacing: -0.5px;">🏆 Predicting the 2026 FIFA World Cup</h1>
#         <p style="color: #666; font-size: 1.1em; font-style: italic;">A Machine Learning Approach to Tournament Forecasting</p>
#         <hr style="border: 0; height: 2px; background: linear-gradient(to right, #2e7d32, #ffd700, transparent); margin-top: 15px;">
#     </div>
#     <h2 style="color: #1b5e20; border-bottom: 1px solid #ddd; padding-bottom: 5px; margin-top: 25px;">📌 Project Overview</h2>
#     <p style="font-size: 1.05em; line-height: 1.6; color: #333;">
#         This data science project aims to predict the potential champions of the <b>2026 FIFA World Cup</b>, tracking the entire tournament timeline from its opening stages on <b>19/06/2026</b> to the final match on <b>20/07/2026</b> (calculated in Australian Time).
#     </p>
#     <p style="font-size: 1.05em; line-height: 1.6; color: #333;">
#         The FIFA World Cup is the premier global football competition held every four years, featuring elite national teams that have successfully navigated intense continental qualification processes.
#     </p>
#     <div style="background-color: #fff; padding: 20px; border-radius: 10px; border: 1px solid #e0e0e0; margin: 20px 0;">
#         <h3 style="color: #2e7d32; margin-top: 0; display: flex; align-items: center; gap: 8px;">
#             ⚙️ The New 48-Team Tournament Structure
#         </h3>
#         <p style="color: #555; font-size: 0.95em;">The 2026 edition introduces an expanded format featuring <b>48 qualified nations</b> playing across three host countries:</p>
#         <ul style="line-height: 1.7; color: #444; padding-left: 20px;">
#             <li><b>The Group Stage (72 Matches):</b> Teams are split into 12 groups (Groups A through L) of 4 teams each.</li>
#             <li><b>The Wildcard Tiebreaker:</b> To form a standard knockout bracket, the tournament selects the <b>top 2 teams from each of the 12 groups</b> (24 teams) plus the <b>8 best third-place teams</b> tournament-wide based on points and goal differentials.</li>
#             <li><b>The Knockout Brackets:</b> These 32 surviving teams enter a single-elimination grid progressing through the <i>Round of 32 → Round of 16 → Quarter-Finals (QF) → Semi-Finals (SF) → World Cup Final</i>.</li>
#         </ul>
#     </div>
#     <h2 style="color: #1b5e20; border-bottom: 1px solid #ddd; padding-bottom: 5px; margin-top: 30px;">🎯 Project Objective & Workflow</h2>
#     <p style="font-size: 1.05em; line-height: 1.6; color: #333;">
#         To leverage the past 4 years of historical international football data, construct highly predictive feature variations, and develop a robust classification pipeline capable of predicting match outcomes stage-by-stage up through the World Cup Final.
#     </p>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin-top: 15px;">
#         <div style="background: #edf7ed; padding: 15px; border-radius: 8px; border-left: 4px solid #4caf50;">
#             <h4 style="margin: 0 0 10px 0; color: #1e4620;">🔁 Notebook Workflow</h4>
#             <ol style="margin: 0; padding-left: 20px; line-height: 1.6; color: #2e7d32; font-size: 0.95em;">
#                 <li>Data Collection & Preparation</li>
#                     <ul>
#                         <li>Scraped 2026 World Cup team-to-group mappings from Wikipedia</li>
#                         <li>Data Collection, Cleaning & Manipulation</li>
#                     </ul>
#                 <li>Analysis & Feature Engineering</li>
#                     <ul>
#                         <li>Exploratory Data Analysis (EDA)</li>
#                         <li>Target Setting & Feature Engineering</li>
#                     </ul>
#                 <li>Modeling & Prediction</li>
#                     <ul>
#                         <li>Model Development, Backtest & Evaluation</li>
#                         <li>XGBoost-Based Round-by-Round Prediction</li>
#                         <li>Monte Carlo Simulation for Championship Probability Estimation</li>
#                     </ul>
#             </ol>
#         </div>
#         <div style="background: #fffdf2; padding: 15px; border-radius: 8px; border-left: 4px solid #ffcc00;">
#             <h4 style="margin: 0 0 10px 0; color: #665200;">🧠 Core Methodologies</h4>
#             <ul style="margin: 0; padding-left: 20px; line-height: 1.6; color: #555; font-size: 0.92em;">
#                 <li><b>Scope Limiting:</b> Trimming window to 4-year cycles.</li>
#                 <li><b>Feature Selection:</b> Extracted 10 critical parameters verified by feature distribution violin plots.</li>
#                 <li><b>Optimization:</b> Hyperparameter tuning via Grid Search with cross-validation.</li>
#                 <li><b>Final Engine:</b> Gradient-boosted architecture (XGBoost) selected based on superior generalization performance.</li>
#             </ul>
#         </div>
#     </div>
#     <h2 style="color: #1b5e20; border-bottom: 1px solid #ddd; padding-bottom: 5px; margin-top: 35px;">📊 Data Sources & Collection</h2>
#     <p style="color: #555; font-size: 0.95em;">Data components were gathered from open public sources across Kaggle:</p>
#     <table style="width: 100%; border-collapse: collapse; margin-top: 10px; background-color: white;">
#         <thead>
#             <tr style="background-color: #2e7d32; color: white; text-align: left;">
#                 <th style="padding: 10px; border: 1px solid #ddd;">Dataset</th>
#                 <th style="padding: 10px; border: 1px solid #ddd;">Scope & Description</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td style="padding: 10px; border: 1px solid #ddd; font-family: monospace; font-weight: bold; color: #c2185b;">results.csv</td>
#                 <td style="padding: 10px; border: 1px solid #ddd; color: #444;">Historical international match data containing dates, teams, tournament tiers, and final scores.</td>
#             </tr>
#             <tr style="background-color: #f9f9f9;">
#                 <td style="padding: 10px; border: 1px solid #ddd; font-family: monospace; font-weight: bold; color: #c2185b;">fifa_ranking-2024-06-20</td>
#                 <td style="padding: 10px; border: 1px solid #ddd; color: #444;">Official historical FIFA rankings, points, and structural confederation details up until June 20, 2024.</td>
#             </tr>
#             <tr>
#                 <td style="padding: 10px; border: 1px solid #ddd; font-family: monospace; font-weight: bold; color: #c2185b;">fifa_ranking_2026-06-08</td>
#                 <td style="padding: 10px; border: 1px solid #ddd; color: #444;">Pre-tournament global standings mapping precise baseline power matrices for teams entering the 2026 games.</td>
#             </tr>
#         </tbody>
#     </table>
#     <div style="margin-top: 15px; padding: 12px 15px; background-color: #fff3cd; border-left: 4px solid #ffc107; border-radius: 4px; color: #664d03; font-size: 0.92em; line-height: 1.5;">
#         <strong>⚠️ Data Limitation & Scope Handling:</strong>
#         The <code>fifa_ranking_2026-06-08</code> dataset provides static team ranks mapped specifically for the tournament baseline rather than an active day-to-day chronological timeline. Consequently, matches played between late 2024 and early 2026 preserve the fixed June 2024 baseline parameters before updating to the active pre-tournament metrics. This represents an accepted baseline constraint within the predictive scope of this project.
#     </div>
#     <h2 style="color: #1b5e20; border-bottom: 1px solid #ddd; padding-bottom: 5px; margin-top: 35px;">🛠️ Technical Infrastructure</h2>
#     <div style="margin-top: 10px; display: flex; flex-wrap: wrap; gap: 8px;">
#         <span style="background: #007acc; color: white; padding: 5px 12px; border-radius: 20px; font-size: 0.85em; font-weight: bold;">Pandas / NumPy</span>
#         <span style="background: #f8991d; color: white; padding: 5px 12px; border-radius: 20px; font-size: 0.85em; font-weight: bold;">Scikit-Learn</span>
#         <span style="background: #111; color: white; padding: 5px 12px; border-radius: 20px; font-size: 0.85em; font-weight: bold;">XGBoost</span>
#         <span style="background: #254a5e; color: white; padding: 5px 12px; border-radius: 20px; font-size: 0.85em; font-weight: bold;">Matplotlib / Seaborn</span>
#         <span style="background: #7b1fa2; color: white; padding: 5px 12px; border-radius: 20px; font-size: 0.85em; font-weight: bold;">GridSearchCV Opt</span>
#     </div>
# </div>

# %% [markdown]
# # PART 1: DATA PREPARATION AND EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ## 1.1 Data Collection

# %%
# import libraries

import kagglehub
import os
import shutil

import pandas as pd
import numpy as np
import requests
from collections import Counter
import random
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
import plotly.graph_objects as go
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
from operator import itemgetter
from itertools import permutations
from itertools import combinations
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import pandas as pd
import requests
from io import BytesIO
from PIL import Image
import builtins

# %%
# path = kagglehub.dataset_download("martj42/international-football-results-from-1872-to-2017")
# rank_path = kagglehub.dataset_download("piterfm/fifa-football-world-cup")

# print("Path to dataset files:", path)

# dest = "./data"
# os.makedirs(dest, exist_ok=True)
# for file in os.listdir(path):
#     shutil.move(os.path.join(path, file), dest)    
#     shutil.move(os.path.join(rank_path, os.listdir(rank_path)), dest)

# path = kagglehub.dataset_download("cashncarry/fifaworldranking")
# for file in os.listdir(path):
#     shutil.move(os.path.join(path, file), dest)

# %%
# Load datasets
result_df = pd.read_csv('data/results.csv')
rank_2024_df = pd.read_csv('data/fifa_ranking-2024-06-20.csv')
rank_2026_df = pd.read_csv('data/fifa_ranking_2026-06-08.csv')

# %% [markdown]
# ## 1.2 Data Cleaning

# %%
# standardize fifa wc team name

result_df['away_team'] = result_df['away_team'].replace('São Tomé and Príncipe', 'Sao Tome and Principe')
result_df['home_team'] = result_df['home_team'].replace('São Tomé and Príncipe', 'Sao Tome and Principe')

name_map = {
    'Korea Republic': 'South Korea',
    'USA': 'United States',
    "Côte d'Ivoire": 'Ivory Coast',
    'IR Iran': 'Iran',
    'Czechia': 'Czech Republic',
    'Cabo Verde': 'Cape Verde',
    'Congo DR': 'DR Congo',
    'Curacao': 'Curaçao',
    'Korea DPR': 'North Korea',
    'China PR': 'China',
    'Kyrgyz Republic': 'Kyrgyzstan',
    'Türkiye': 'Turkey',
    'St Lucia': 'Saint Lucia',
    'The Gambia': 'Gambia',
    'St Kitts and Nevis': 'Saint Kitts and Nevis',
    'Hong Kong, China': 'Hong Kong',
    'São Tomé and Príncipe': 'Sao Tome and Principe'
}

rank_2024_df['country_full'] = rank_2024_df['country_full'].replace(name_map)
rank_2026_df['team'] = rank_2026_df['team'].replace(name_map)

# %%
# get the 2026 world cup teams
team_2026_list = result_df[result_df.isna().any(axis=1)]['home_team'].unique().tolist()
print("total team:", len(team_2026_list))
# Out:
# total team: 48

# %%
# get the host country name
host_country_list = result_df[result_df.isna().any(axis=1)]['country'].unique().tolist()
print("host country:", host_country_list)
# Out:
# host country: ['Mexico', 'Canada', 'United States']

# %%
# get the data from 2010 onwards for exploration
result_df['date'] = pd.to_datetime(result_df['date'])
mask = result_df['date'] >= pd.to_datetime('2010-01-01')
result_df = result_df[mask].reset_index(drop=True)

# %% [markdown]
# ## 1.3 Data Preprocessing

# %%
# clean and merge the ranking datasets

rank_2024_df['rank_date'] = pd.to_datetime(rank_2024_df['rank_date'])
mask = rank_2024_df['rank_date'] >= pd.to_datetime('2010-01-01')
rank_2024_df = rank_2024_df[mask].reset_index(drop=True)

# %%
date_range = pd.date_range(rank_2024_df['rank_date'].min(), rank_2024_df['rank_date'].max(), freq='D')
countries = rank_2024_df['country_full'].unique()

full_grid = pd.MultiIndex.from_product([countries, date_range], names=['country_full', 'rank_date'])
full_grid_df = pd.DataFrame(index=full_grid).reset_index()
new_rank_df = pd.merge(full_grid_df, rank_2024_df, on=['country_full', 'rank_date'], how='left')

# forward fill per country — carries previous rank forward
new_rank_df = new_rank_df.sort_values(['country_full', 'rank_date'])
new_rank_df = new_rank_df.set_index('rank_date')
new_rank_df = new_rank_df.groupby('country_full')[new_rank_df.columns].ffill()
new_rank_df = new_rank_df.reset_index()

print(new_rank_df.columns.tolist())
new_rank_df.head()
# Out:
# ['rank_date', 'country_full', 'rank', 'country_abrv', 'total_points', 'previous_points', 'rank_change', 'confederation']
#    rank_date country_full   rank country_abrv  total_points  previous_points  \
# 0 2010-02-03  Afghanistan  194.0          AFG          20.0             20.0
# 1 2010-02-04  Afghanistan  194.0          AFG          20.0             20.0
# 2 2010-02-05  Afghanistan  194.0          AFG          20.0             20.0
# 3 2010-02-06  Afghanistan  194.0          AFG          20.0             20.0
# 4 2010-02-07  Afghanistan  194.0          AFG          20.0             20.0
#
#    rank_change confederation
# 0          1.0           AFC
# 1          1.0           AFC
# 2          1.0           AFC
# 3          1.0           AFC
# 4          1.0           AFC

# %%
# add prefix to ranking columns before merge
home_rank_df = new_rank_df.add_prefix('home_')
away_rank_df = new_rank_df.add_prefix('away_')

merged_df = pd.merge(result_df, home_rank_df,
         left_on=['home_team', 'date'],
         right_on=['home_country_full', 'home_rank_date'],
         how='left')\
        .merge(away_rank_df,
         left_on=['away_team', 'date'],
         right_on=['away_country_full', 'away_rank_date'],
         how='left')

# %%
# the ranking data after 2024-06-20 is not available, i found the other data for ranking each team before world cup 2026 
# we will use these scores and rank for the missing ranking after 2024-06-20

rank_2026_df.rename(columns={'team': 'country_full', 'team_code': 'country_abrv', 'association': 'confederation'}, inplace=True)
rank_2026_df['rank_change'] = rank_2026_df['rank'] - rank_2026_df['previous_rank']

# %%
temp_df = merged_df[merged_df['date'] > pd.to_datetime('2024-06-20')]

# create a lookup dict from your ranking df
rank_lookup = rank_2026_df.set_index('country_full')['rank'].to_dict()
previous_rank_lookup = rank_2026_df.set_index('country_full')['previous_rank'].to_dict()
points_lookup = rank_2026_df.set_index('country_full')['points'].to_dict()
previous_points_lookup = rank_2026_df.set_index('country_full')['previous_points'].to_dict()
rank_change_lookup = rank_2026_df.set_index('country_full')['rank_change'].to_dict()
confederation_lookup = rank_2026_df.set_index('country_full')['confederation'].to_dict()

# fill NaN by mapping country name
temp_df['home_rank'] = temp_df['home_rank'].fillna(temp_df['home_team'].map(rank_lookup))
temp_df['away_rank'] = temp_df['away_rank'].fillna(temp_df['away_team'].map(rank_lookup))
temp_df['home_total_points'] = temp_df['home_total_points'].fillna(temp_df['home_team'].map(points_lookup))
temp_df['away_total_points'] = temp_df['away_total_points'].fillna(temp_df['away_team'].map(points_lookup))
temp_df['home_previous_points'] = temp_df['home_previous_points'].fillna(temp_df['home_team'].map(previous_points_lookup))
temp_df['away_previous_points'] = temp_df['away_previous_points'].fillna(temp_df['away_team'].map(previous_points_lookup))
temp_df['home_rank_change'] = temp_df['home_rank_change'].fillna(temp_df['home_team'].map(rank_change_lookup))
temp_df['away_rank_change'] = temp_df['away_rank_change'].fillna(temp_df['away_team'].map(rank_change_lookup))
temp_df['home_confederation'] = temp_df['home_confederation'].fillna(temp_df['home_team'].map(confederation_lookup))
temp_df['away_confederation'] = temp_df['away_confederation'].fillna(temp_df['away_team'].map(confederation_lookup))

# %%
# split, modify, recombine
before = merged_df[merged_df['date'] <= pd.to_datetime('2024-06-20')]
after = temp_df 

merged_df = pd.concat([before, after]).sort_values('date').reset_index(drop=True)
merged_df.head()
# Out:
#         date home_team    away_team  home_score  away_score tournament  \
# 0 2010-01-02      Iran  North Korea         1.0         0.0   Friendly
# 1 2010-01-02     Qatar         Mali         0.0         0.0   Friendly
# 2 2010-01-02     Syria     Zimbabwe         6.0         0.0   Friendly
# 3 2010-01-02     Yemen   Tajikistan         0.0         1.0   Friendly
# 4 2010-01-03    Angola       Gambia         1.0         1.0   Friendly
#
#                          city   country  neutral home_rank_date  ...  \
# 0                        Doha     Qatar     True            NaT  ...
# 1                        Doha     Qatar    False            NaT  ...
# 2                Kuala Lumpur  Malaysia     True            NaT  ...
# 3                      Sana'a     Yemen    False            NaT  ...
# 4  Vila Real de Santo António  Portugal     True            NaT  ...
#
#   home_rank_change  home_confederation away_rank_date  away_country_full  \
# ...

# %%
# only use the data from 2022-06-11 to 2026-06-10 for model training, as the ranking data before 2022 is not relevant to the current team performance and may introduce noise
final_df = merged_df.copy()
final_df.drop(columns=['home_country_full', 'home_rank_date', 'away_country_full', 'away_rank_date', 'home_country_abrv', 'away_country_abrv'], inplace=True)
print(final_df.columns)

# keep only 2026 world cup teams 
final_df = final_df[final_df['home_team'].isin(team_2026_list)].reset_index(drop=True)

# remove 2026 world cup matches data
world_cup_2026_df = final_df[final_df['date'] >= pd.to_datetime('2026-06-11')].reset_index(drop=True)
final_df = final_df[final_df['date'] < pd.to_datetime('2026-06-11')].reset_index(drop=True)
final_df = final_df[final_df['date'] >= pd.to_datetime('2022-06-11')].reset_index(drop=True)
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral', 'home_rank',
#        'home_total_points', 'home_previous_points', 'home_rank_change',
#        'home_confederation', 'away_rank', 'away_total_points',
#        'away_previous_points', 'away_rank_change', 'away_confederation'],
#       dtype='str')

# %%
# all rows with any NaN in ranking columns
ranking_cols = ['home_rank', 'home_total_points', 'away_rank', 'away_total_points']
missing_rows = final_df[final_df[ranking_cols].isna().any(axis=1)]

print(f"Total missing rows: {len(missing_rows)}")
missing_rows.head(20)
# Out:
# Total missing rows: 6
#           date home_team     away_team  home_score  away_score  \
# 296 2023-06-27    Canada    Guadeloupe         2.0         2.0
# 323 2023-09-07    Panama    Martinique         3.0         0.0
# 737 2024-09-09     Haiti  Sint Maarten         6.0         0.0
# 738 2024-09-09   Curaçao  Saint Martin         4.0         0.0
# 812 2024-11-15   Curaçao  Saint Martin         5.0         0.0
# 954 2025-06-16    Panama    Guadeloupe         5.0         2.0
#
#                   tournament            city        country  neutral  \
# 296                 Gold Cup         Toronto         Canada    False
# 323  CONCACAF Nations League     Panama City         Panama    False
# 737  CONCACAF Nations League        Mayagüez    Puerto Rico     True
# 738  CONCACAF Nations League  Saint George's        Grenada     True
# 812  CONCACAF Nations League      Willemstad        Curaçao    False
# 954                 Gold Cup          Carson  United States     True
#
# ...

# %%
# fill non-FIFA away team rankings with worst values
non_fifa_mask = final_df['away_rank'].isna()

final_df.loc[non_fifa_mask, 'away_rank'] = final_df['away_rank'].max()
final_df.loc[non_fifa_mask, 'away_total_points'] = final_df['away_total_points'].min()
final_df.loc[non_fifa_mask, 'away_previous_points'] = final_df['away_total_points'].min()
final_df.loc[non_fifa_mask, 'away_rank_change'] = 0
final_df.loc[non_fifa_mask, 'away_confederation'] = 'CONCACAF'  # all these teams are CONCACAF

# %%
print('missing:', sum(final_df.isna().sum()))
print('duplicate:', final_df.duplicated().sum())
# Out:
# missing: 0
# duplicate: 0

# %% [markdown]
# ## 1.4 Feature Engineering

# %%
# Creating new features based on domain-specific knowledge

def assign_result(home_score, away_score):
    if home_score > away_score:
        return pd.Series([0, 3, 0])
    if home_score < away_score:
        return pd.Series([1, 0, 3])
    else:
        return pd.Series([2, 1, 1])

results = final_df.apply(lambda x: assign_result(x["home_score"], x["away_score"]), axis=1)
final_df[['result', 'home_team_points', 'away_team_points']] = results

# %%
final_df["rank_dif"] = final_df["home_rank"] - final_df["away_rank"]
final_df["score_dif"] = final_df["home_score"] - final_df["away_score"]
final_df["points_home_by_rank"] = final_df["home_team_points"]/final_df["away_rank"]
final_df["points_away_by_rank"] = final_df["away_team_points"]/final_df["home_rank"]

# %%
home_df = final_df[['date','home_team', 'home_score', 'away_score', 'home_rank', 'away_rank', 'home_total_points',
       'home_previous_points', 'home_rank_change', 'home_confederation',
       'home_team_points', 'points_home_by_rank', 'result', 'rank_dif']]
home_df.columns = [h.replace("home_", "").replace("_home", "").replace("away_", "suf_").replace("_away", "_suf") for h in home_df.columns]
away_df = final_df[['date','away_team', 'away_score', 'home_score', 'away_rank', 'home_rank', 'away_total_points',
       'away_previous_points', 'away_rank_change', 'away_confederation',
       'away_team_points', 'points_away_by_rank', 'result', 'rank_dif']]
away_df.columns = [h.replace("away_", "").replace("_away", "").replace("home_", "suf_").replace("_home", "_suf") for h in away_df.columns]
team_df = pd.concat([home_df, away_df], ignore_index=True)

# %%
new_val = []
for idx, row in team_df.iterrows():
   team= row['team']
   date = row['date']
   past_games = team_df.loc[(team_df["team"] == team) & (team_df["date"] < date)].sort_values(by=['date'], ascending=False)
   last5 = past_games.head(5)
   goals = past_games["score"].mean()
   goals_l5 = last5["score"].mean()
   goals_suf = past_games["suf_score"].mean()
   goals_suf_l5 = last5["suf_score"].mean()
   rank = past_games["suf_rank"].mean()
   rank_l5 = last5["suf_rank"].mean()
   if len(last5) > 0:
    points = past_games["total_points"].values[0] - past_games["total_points"].values[-1]
    points_l5 = last5["total_points"].values[0] - last5["total_points"].values[-1] 
   else:
    points = 0
    points_l5 = 0
   gp = past_games["team_points"].mean()
   gp_l5 = last5["team_points"].mean()
   gp_rank = past_games["points_by_rank"].mean()
   gp_rank_l5 = last5["points_by_rank"].mean()
   
   new_val.append([goals, goals_l5, goals_suf, goals_suf_l5, rank, rank_l5, points, points_l5, gp, gp_l5, gp_rank, gp_rank_l5])

# %%
cols =["goals_mean", "goals_mean_l5", "goals_suf_mean", "goals_suf_mean_l5", "rank_mean", "rank_mean_l5", 
       "points_mean", "points_mean_l5", "game_points_mean", "game_points_mean_l5", "game_points_rank_mean", "game_points_rank_mean_l5"]

new_val_df = pd.DataFrame(new_val, columns=cols)

# %%
agg_team_df = pd.concat([team_df, new_val_df], axis=1).reset_index(drop=True)
agg_team_df.columns[-12:]
home_agg_df = agg_team_df[:int(len(agg_team_df)/2)]
away_agg_df = agg_team_df[int(len(agg_team_df)/2):].reset_index(drop=True)

# get only the nw cols to merge back to final df
home_agg_df = home_agg_df.iloc[:, -12:]
away_agg_df = away_agg_df.iloc[:, -12:]

home_agg_df.columns = ['home_' + str(col) for col in home_agg_df.columns]
away_agg_df.columns = ['away_' + str(col) for col in away_agg_df.columns]

# %%
temp_agg_df = pd.concat([home_agg_df, away_agg_df], axis=1)
final_team_df = pd.concat([final_df, temp_agg_df], axis=1).reset_index(drop=True)
final_team_df['is_friendly'] = [1 if val == 'Friendly' else 0 for val in final_team_df['tournament']]
final_team_df = pd.get_dummies(final_team_df, columns=["is_friendly"])

# %%
drop_cols = ['tournament', 'city', 'country', 'neutral', 'home_total_points', 'home_previous_points',
       'home_confederation', 'away_total_points',
       'away_previous_points','away_confederation', 'home_team_points', 'away_team_points',
       'score_dif', 'points_home_by_rank', 'points_away_by_rank']
agg_df = final_team_df.drop(columns=drop_cols)

# %%
missing = agg_df.isna().sum()

plt.figure(figsize=(16, 6))

missing.plot(kind="bar")

plt.title("Missing Values by Feature")
plt.xlabel("Features")
plt.ylabel("Number of Missing Values")

plt.xticks(rotation=90)
plt.grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# drop null values rows
agg_df = agg_df.dropna().reset_index(drop=True)

# assign draw games as a lose of the home team and will create a binary problem
agg_df['target'] = agg_df['result'].apply(lambda x: 1 if x == 2 else x)

scaled_df = agg_df[list(agg_df.columns[6:].values)]
scaled_df.drop(columns = ['away_rank', 'result', 'target'], inplace=True)
feature_cols = scaled_df.columns
scaled_df[feature_cols] = scaled_df[feature_cols].astype('float64')

st = StandardScaler()
scaled = st.fit_transform(scaled_df)
scaled_df = pd.DataFrame(scaled, columns=feature_cols)
scaled_df = pd.concat([scaled_df, agg_df['target']], axis=1)
scaled_df.head()
# Out:
#    home_rank_change  away_rank_change  rank_dif  home_goals_mean  \
# 0         -0.438242         -1.072937 -1.909132         4.311454
# 1          0.626264         -0.538851  0.659842         0.537712
# 2          0.094011         -0.004764  0.159688         6.198325
# 3         -0.438242         -0.004764  0.955387        -1.349160
# 4          0.094011         -0.004764  1.273667        -3.236031
#
#    home_goals_mean_l5  home_goals_suf_mean  home_goals_suf_mean_l5  \
# 0            2.615843            -0.086073                0.008288
# 1            0.240709            -0.086073                0.008288
# 2            3.803410             2.287237                1.734245
# 3           -0.946858             2.287237                1.734245
# 4           -2.134425             2.287237                1.734245
#
#    home_rank_mean  home_rank_mean_l5  home_points_mean  ...  \
# 0       -1.020964          -0.888288         -0.770228  ...
# ...

# %%
scaled_df['target'].value_counts().plot(kind = 'bar', title = 'Target Distribution');

# %% [markdown]
# ## 1.4 Exploratory Data Analysis

# %%
print('Total columns:', scaled_df.shape[1])
print('Total rows:', scaled_df.shape[0])
# Out:
# Total columns: 30
# Total rows: 1121

# %%
# Split the dataset into two chunks for separate violin plots, each plot represent 15 columns of the dataset
# This helps identify which features show the greatest separation between winners and losers.

half_cols = int(np.floor(len(scaled_df.columns)/2))
melted_df1 = pd.melt(scaled_df.iloc[:, :half_cols].join(agg_df['target']), id_vars=['target'], var_name='feature', value_name='value')
melted_df2 = pd.melt(scaled_df.iloc[:, half_cols:], id_vars=['target'], var_name='feature', value_name='value')

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5))

sns.violinplot(x="feature", y="value", hue="target", data=melted_df1, split=True, inner="quart", ax=axes[0])
axes[0].set_title("Dataset 1")
axes[0].tick_params(axis="x", rotation=90)

sns.violinplot(x="feature", y="value", hue="target", data=melted_df2, split=True, inner="quart", ax=axes[1])
axes[1].set_title("Dataset 2")
axes[1].tick_params(axis="x", rotation=90)

# %% [markdown]
# The above features do not seperate target classes very well, try to create different features and see if we can use them for modeling

# %%
# Create 10 new features by combining and transforming the available features
df = scaled_df.copy()
df["goal_diff_mean"]     = df["home_goals_mean"] - df["away_goals_mean"]
df["defense_diff_mean"]  = df["away_goals_suf_mean"] - df["home_goals_suf_mean"]
df["rank_diff"]          = df["away_rank_change"] - df["home_rank_change"]
df["form_diff_l5"]       = df["home_goals_mean_l5"] - df["away_goals_mean_l5"]
df["points_diff_mean"]   = df["home_points_mean"] - df["away_points_mean"]
df["game_points_diff"]   = df["home_game_points_mean"] - df["away_game_points_mean"]
df["attack_vs_defense"]  = df["home_goals_mean"] - df["away_goals_suf_mean"]
df["suf_diff_l5"]        = df["home_goals_suf_mean_l5"] - df["away_goals_suf_mean_l5"]
df["rank_x_form"]        = df["rank_diff"] * df["form_diff_l5"]
df["points_momentum"]    = df["home_game_points_mean_l5"] - df["home_game_points_mean"]

new_features = [
    "goal_diff_mean", "defense_diff_mean", "rank_diff",
    "form_diff_l5", "points_diff_mean", "game_points_diff",
    "attack_vs_defense", "suf_diff_l5", "rank_x_form", "points_momentum"
]

# %%
violin3 = df[df.columns[-11:]]
melted_df3 = pd.melt(violin3, id_vars=['target'], var_name='feature', value_name='value')
plt.figure(figsize=(10,5))
sns.violinplot(x="feature", y="value", hue="target", data=melted_df3, split=True, inner="quart")
plt.xticks(rotation=90)
plt.show()

# %%
# Create more 8 new features by combining and transforming the available features.

df.loc[:, "goals_dif"] = df["home_goals_mean"] - df["away_goals_mean"]
df.loc[:, "goals_dif_l5"] = df["home_goals_mean_l5"] - df["away_goals_mean_l5"]
df.loc[:, "goals_suf_dif"] = df["home_goals_suf_mean"] - df["away_goals_suf_mean"]
df.loc[:, "goals_suf_dif_l5"] = df["home_goals_suf_mean_l5"] - df["away_goals_suf_mean_l5"]
df.loc[:, "goals_made_suf_dif"] = df["home_goals_mean"] - df["away_goals_suf_mean"]
df.loc[:, "goals_made_suf_dif_l5"] = df["home_goals_mean_l5"] - df["away_goals_suf_mean_l5"]
df.loc[:, "goals_suf_made_dif"] = df["home_goals_suf_mean"] - df["away_goals_mean"]
df.loc[:, "goals_suf_made_dif_l5"] = df["home_goals_suf_mean_l5"] - df["away_goals_mean_l5"]

# %%
melted_df4 = pd.melt(df.iloc[:, -8:].join(df['target']), id_vars=['target'], var_name='feature', value_name='value')
plt.figure(figsize=(10,5))
sns.violinplot(x="feature", y="value", hue="target", data=melted_df4, split=True, inner="quart")
plt.xticks(rotation=90)
plt.show()

# %%
# create another 10 new features
df.loc[:, "dif_points"] = df["home_game_points_mean"] - df["away_game_points_mean"]
df.loc[:, "dif_points_l5"] = df["home_game_points_mean_l5"] - df["away_game_points_mean_l5"]
df.loc[:, "dif_points_rank"] = df["home_game_points_rank_mean"] - df["away_game_points_rank_mean"]
df.loc[:, "dif_points_rank_l5"] = df["home_game_points_rank_mean_l5"] - df["away_game_points_rank_mean_l5"]
df.loc[:, "dif_rank_agst"] = df["home_rank_mean"] - df["away_rank_mean"]
df.loc[:, "dif_rank_agst_l5"] = df["home_rank_mean_l5"] - df["away_rank_mean_l5"]
df.loc[:, "goals_per_ranking_dif"] = (df["home_goals_mean"] / df["home_rank_mean"]) - (df["away_goals_mean"] / df["away_rank_mean"])
df.loc[:, "goals_per_ranking_suf_dif"] = (df["home_goals_suf_mean"] / df["home_rank_mean"]) - (df["away_goals_suf_mean"] / df["away_rank_mean"])
df.loc[:, "goals_per_ranking_dif_l5"] = (df["home_goals_mean_l5"] / df["home_rank_mean"]) - (df["away_goals_mean_l5"] / df["away_rank_mean"])
df.loc[:, "goals_per_ranking_suf_dif_l5"] = (df["home_goals_suf_mean_l5"] / df["home_rank_mean"]) - (df["away_goals_suf_mean_l5"] / df["away_rank_mean"])

# %%
scaled = st.fit_transform(df.iloc[:, -10:])
scaled_df = pd.DataFrame(scaled, columns=df.columns[-10:])
scaled_df = pd.concat([scaled_df, df['target']], axis=1)
melted_df5 = pd.melt(scaled_df, id_vars=['target'], var_name='feature', value_name='value')

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x="feature", y="value", hue="target", data=melted_df5, split=True, inner="quart")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="feature", y="value", hue="target", data=melted_df5)
plt.xticks(rotation=90)
plt.show()

# %%
sns.jointplot(data = scaled_df, x = 'goals_per_ranking_dif', y = 'goals_per_ranking_dif_l5', kind="reg")
plt.show()

# %%
sns.jointplot(data = scaled_df, x = 'dif_rank_agst', y = 'dif_rank_agst_l5', kind="reg")
plt.show()

# %%
sns.jointplot(data = scaled_df, x = 'dif_points', y = 'dif_points_l5', kind="reg")
plt.show()

# %%
sns.jointplot(data = scaled_df, x = 'dif_points_rank', y = 'dif_points_rank_l5', kind="reg")
plt.show()

# %% [markdown]
# ## 1.6 Feature Selection

# %% [markdown]
# Features to be used for predictions:
# - rank_dif
# - goals_dif
# - goals_dif_l5
# - goals_suf_dif
# - goals_suf_dif_l5
# - dif_rank_agst
# - dif_rank_agst_l5
# - goals_per_ranking_dif
# - dif_points_rank
# - dif_points_rank_l5
# - is_friendly

# %%
predicted_cols = ['home_team', 'away_team','rank_dif',"home_goals_mean", "home_rank_mean", "away_goals_mean", "away_rank_mean", "home_rank_mean_l5", 
                  "away_rank_mean_l5", "home_goals_suf_mean", "away_goals_suf_mean", "home_goals_mean_l5", "away_goals_mean_l5", 
                  "home_goals_suf_mean_l5", "away_goals_suf_mean_l5", "home_game_points_rank_mean", 
                  "home_game_points_rank_mean_l5", "away_game_points_rank_mean", "away_game_points_rank_mean_l5","is_friendly_0", "is_friendly_1", "target"]

temp_df = agg_df[predicted_cols].copy()
temp_df.loc[:, "goals_dif"] = temp_df["home_goals_mean"] - temp_df["away_goals_mean"]
temp_df.loc[:, "goals_dif_l5"] = temp_df["home_goals_mean_l5"] - temp_df["away_goals_mean_l5"]
temp_df.loc[:, "goals_suf_dif"] = temp_df["home_goals_suf_mean"] - temp_df["away_goals_suf_mean"]
temp_df.loc[:, "goals_suf_dif_l5"] = temp_df["home_goals_suf_mean_l5"] - temp_df["away_goals_suf_mean_l5"]
temp_df.loc[:, "goals_per_ranking_dif"] = (temp_df["home_goals_mean"] / temp_df["home_rank_mean"]) - (temp_df["away_goals_mean"] / temp_df["away_rank_mean"])
temp_df.loc[:, "dif_rank_agst"] = temp_df["home_rank_mean"] - temp_df["away_rank_mean"]
temp_df.loc[:, "dif_rank_agst_l5"] = temp_df["home_rank_mean_l5"] - temp_df["away_rank_mean_l5"]
temp_df.loc[:, "dif_points_rank"] = temp_df["home_game_points_rank_mean"] - temp_df["away_game_points_rank_mean"]
temp_df.loc[:, "dif_points_rank_l5"] = temp_df["home_game_points_rank_mean_l5"] - temp_df["away_game_points_rank_mean_l5"]

predict_df = temp_df[["home_team", "away_team", "target", "rank_dif", "goals_dif", "goals_dif_l5", "goals_suf_dif", 
                         "goals_suf_dif_l5", "goals_per_ranking_dif", "dif_rank_agst", "dif_rank_agst_l5", "dif_points_rank", 
                         "dif_points_rank_l5", "is_friendly_0", "is_friendly_1"]]

# %% [markdown]
# ## 1.7 Final Dataset Summary

# %%
print('Number of rows and columns:', predict_df.shape)
predict_df.describe()
# Out:
# Number of rows and columns: (1121, 15)
#             target     rank_dif    goals_dif  goals_dif_l5  goals_suf_dif  \
# count  1121.000000  1121.000000  1121.000000   1121.000000    1121.000000
# mean      0.415700   -33.024086     0.636552      0.712459      -0.570312
# std       0.493062    44.006070     0.874358      1.159497       1.059403
# min       0.000000  -197.000000    -4.000000     -4.000000      -7.642857
# 25%       0.000000   -60.000000     0.028571      0.000000      -1.076923
# 50%       0.000000   -29.000000     0.700000      0.700000      -0.393939
# 75%       1.000000    -2.000000     1.251724      1.400000       0.113636
# max       1.000000    77.000000     4.000000      4.800000       2.000000
#
#        goals_suf_dif_l5  goals_per_ranking_dif  dif_rank_agst  \
# count       1121.000000            1121.000000    1121.000000
# mean          -0.625439               0.006768      12.204907
# std            1.192324               0.034816      26.750584
# ...

# %%
# train test split
X = predict_df.drop(columns=["home_team", "away_team", "target"])
y = predict_df["target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)

print(' ')
print("Train target distribution:", y_train.value_counts())
print(' ')
print("Test target distribution:", y_test.value_counts())
# Out:
# X_train shape: (896, 12)
# X_test shape: (225, 12)
#
# Train target distribution: target
# 0    524
# 1    372
# Name: count, dtype: int64
#
# Test target distribution: target
# 0    131
# 1     94
# Name: count, dtype: int64

# %% [markdown]
# # Part 2: Predictive Model Development

# %%
# helper function to visualize model performance

def analyze(model):
    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test.values)[:,1])
    fpr_train, tpr_train, _ = roc_curve(y_train, model.predict_proba(X_train.values)[:,1])
    
    auc_test = roc_auc_score(y_test, model.predict_proba(X_test.values)[:,1])
    auc_train = roc_auc_score(y_train, model.predict_proba(X_train.values)[:,1])
    
    cm = confusion_matrix(y_test, model.predict(X_test.values))

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    
    axes[0].plot([0, 1], [0, 1], 'k--')
    axes[0].plot(fpr, tpr, label=f"Test (AUC: {auc_test:.2f})")
    axes[0].plot(fpr_train, tpr_train, label=f"Train (AUC: {auc_train:.2f})")
    axes[0].set_title('ROC Curves')
    axes[0].set_xlabel('False Positive Rate')
    axes[0].set_ylabel('True Positive Rate')
    axes[0].legend()

    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=axes[1])
    axes[1].set_title('Test Confusion Matrix')
    axes[1].set_xlabel('Predicted')
    axes[1].set_ylabel('Actual')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 2.1 Gradent Boosting

# %%
gb = GradientBoostingClassifier(random_state=42)
params_gb = {"learning_rate": [0.01, 0.1, 0.5],
            "min_samples_split": [5, 10],
            "min_samples_leaf": [3, 5],
            "max_depth":[3,5,10],
            "max_features":["sqrt"],
            "n_estimators":[100, 200]
         } 

gb_cv = GridSearchCV(gb, params_gb, cv = 3, n_jobs = -1, verbose = False)

gb_cv.fit(X_train.values, np.ravel(y_train))
best_gb = gb_cv.best_estimator_

analyze(best_gb)

# %% [markdown]
# ## 2.2 Random Forest

# %%
rf = RandomForestClassifier(random_state=42)
params_rf = {
    "max_depth":        [5, 8, 10],       # was 20 — way too deep
    "min_samples_split":[20, 30],         # was 10 — increase to avoid small splits
    "max_leaf_nodes":   [50, 100],        # was 175 — fewer leaves
    "min_samples_leaf": [10, 20],         # was 5 — larger leaf size
    "n_estimators":     [200, 300],
    "max_features":     ["sqrt"],
    "class_weight":     ["balanced"],     # handles 131/94 imbalance
}

rf_cv = GridSearchCV(rf, params_rf, cv=3, 
                     n_jobs=-1, verbose=True,
                     scoring='roc_auc')

rf_cv.fit(X_train.values, np.ravel(y_train))
best_rf = rf_cv.best_estimator_

analyze(best_rf)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits

# %% [markdown]
# ## 2.3 XGBoost

# %%
xgb = XGBClassifier(eval_metric='logloss',random_state=42,n_jobs=-1)
params_xgb = {
    "n_estimators":     [100, 200],
    "max_depth":        [2, 3],
    "learning_rate":    [0.01, 0.05],
    "subsample":        [0.6, 0.7],
    "colsample_bytree": [0.6, 0.7],
    "min_child_weight": [5, 10],
    "reg_alpha":        [0.5, 1.0],
    "reg_lambda":       [2.0, 5.0],
    "gamma":            [0.3, 0.5],
}

xgb_cv = GridSearchCV(xgb, params_xgb, cv=3,
                       n_jobs=-1, verbose=True,
                       scoring='roc_auc')

xgb_cv.fit(X_train.values, np.ravel(y_train))
best_xgb = xgb_cv.best_estimator_
analyze(best_xgb)
# Out:
# Fitting 3 folds for each of 512 candidates, totalling 1536 fits

# %% [markdown]
# --> All three models achieved nearly identical AUC scores, indicating that model selection should be based on other factors such as interpretability, complexity, training time, or robustness rather than predictive performance alone.

# %%
# plot feature importances
importances = pd.Series(best_xgb.feature_importances_, index=X_train.columns)
importances.nlargest(10).plot(kind='barh')
plt.title('Top 10 Most Important Features')
plt.show()

# %% [markdown]
# # Part 3. FIFA World Cup Tournament Simulation

# %% [markdown]
# ## 3.1 Group Stage

# %%
groups = {
    'A': ['Mexico', 'South Africa', 'South Korea', 'Czech Republic'],
    'B': ['Switzerland', 'Canada', 'Bosnia and Herzegovina', 'Qatar'],
    'C': ['Brazil', 'Morocco', 'Scotland', 'Haiti'],
    'D': ['United States', 'Australia', 'Paraguay', 'Turkey'],
    'E': ['Germany', 'Ivory Coast', 'Ecuador', 'Curaçao'],
    'F': ['Netherlands', 'Japan', 'Sweden', 'Tunisia'],
    'G': ['Belgium', 'Egypt', 'Iran', 'New Zealand'],
    'H': ['Spain', 'Cape Verde', 'Uruguay', 'Saudi Arabia'],
    'I': ['France', 'Norway', 'Senegal', 'Iraq'],
    'J': ['Argentina', 'Austria', 'Algeria', 'Jordan'],
    'K': ['Colombia', 'Portugal', 'DR Congo', 'Uzbekistan'],
    'L': ['England', 'Croatia', 'Ghana', 'Panama'],
}

# ISO 3166-1 alpha-2 codes used by flagcdn.com (gb-eng / gb-sct are special subdivision codes)
TEAM_ISO = {
    'Mexico': 'mx', 'South Africa': 'za', 'South Korea': 'kr', 'Czechia': 'cz',
    'Switzerland': 'ch', 'Canada': 'ca', 'Bosnia and Herzegovina': 'ba', 'Qatar': 'qa',
    'Brazil': 'br', 'Morocco': 'ma', 'Scotland': 'gb-sct', 'Haiti': 'ht',
    'USA': 'us', 'Australia': 'au', 'Paraguay': 'py', 'Turkiye': 'tr',
    'Germany': 'de', 'Ivory Coast': 'ci', 'Ecuador': 'ec', 'Curacao': 'cw',
    'Netherlands': 'nl', 'Japan': 'jp', 'Sweden': 'se', 'Tunisia': 'tn',
    'Belgium': 'be', 'Egypt': 'eg', 'Iran': 'ir', 'New Zealand': 'nz',
    'Spain': 'es', 'Cape Verde': 'cv', 'Uruguay': 'uy', 'Saudi Arabia': 'sa',
    'France': 'fr', 'Norway': 'no', 'Senegal': 'sn', 'Iraq': 'iq',
    'Argentina': 'ar', 'Austria': 'at', 'Algeria': 'dz', 'Jordan': 'jo',
    'Colombia': 'co', 'Portugal': 'pt', 'DR Congo': 'cd', 'Uzbekistan': 'uz',
    'England': 'gb-eng', 'Croatia': 'hr', 'Ghana': 'gh', 'Panama': 'pa',
}

rows = []
for group, teams in groups.items():
    for team in teams:
        rows.append({'group': group, 'team': team})
wc_team = pd.DataFrame(rows)


def get_flag_image(iso_code, width=40):
    """Download a small flag PNG from flagcdn.com and return as a numpy array."""
    url = f"https://flagcdn.com/w{width}/{iso_code}.png"
    resp = requests.get(url, timeout=5)
    img = Image.open(BytesIO(resp.content)).convert("RGBA")
    return img


def visualize_groups_flags(wc_team, group_col='group', team_col='team'):
    groups = sorted(wc_team[group_col].unique())
    n_cols, n_rows = 3, 4

    palette = ['#4C72B0', '#DD8452', '#55A868', '#C44E52',
               '#8172B2', '#937860', '#DA8BC3', '#8C8C8C',
               '#CCB974', '#64B5CD', '#4C956C', '#E07A5F']

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(9, 10))
    fig.patch.set_facecolor('#0f0f0f')
    axes = axes.flatten()

    for idx, group in enumerate(groups):
        ax = axes[idx]
        color = palette[idx % len(palette)]
        group_teams = wc_team[wc_team[group_col] == group].reset_index(drop=True)

        ax.set_xlim(0, 1)
        ax.set_ylim(0, 1)
        ax.axis('off')
        ax.set_facecolor('#0f0f0f')

        card = patches.FancyBboxPatch((0.03, 0.03), 0.94, 0.94,
                                        boxstyle="round,pad=0.02,rounding_size=0.06",
                                        linewidth=0, facecolor='#1a1a1a', zorder=0,
                                        transform=ax.transAxes)
        ax.add_patch(card)

        accent = patches.FancyBboxPatch((0.03, 0.88), 0.94, 0.09,
                                          boxstyle="round,pad=0,rounding_size=0.04",
                                          linewidth=0, facecolor=color, zorder=1,
                                          transform=ax.transAxes)
        ax.add_patch(accent)
        ax.text(0.5, 0.925, f"GROUP {group}", fontsize=13, fontweight='bold',
                 color='white', ha='center', va='center', zorder=2)

        n_teams = len(group_teams)
        top, bottom = 0.78, 0.08
        for i, row in group_teams.iterrows():
            y_pos = top - i * (top - bottom) / (n_teams - 1)
            team_name = row[team_col]
            iso_code = TEAM_ISO.get(team_name)

            # Flag image
            if iso_code:
                try:
                    flag_img = get_flag_image(iso_code)
                    imagebox = OffsetImage(flag_img, zoom=0.5)
                    ab = AnnotationBbox(imagebox, (0.12, y_pos), frameon=False,
                                          xycoords='axes fraction', zorder=2)
                    ax.add_artist(ab)
                except Exception:
                    pass  # fallback: skip flag if download fails

            # Team name
            ax.text(0.24, y_pos, team_name, fontsize=11.5,
                     color='#e8e8e8', ha='left', va='center', zorder=2)

    for j in range(idx + 1, len(axes)):
        axes[j].axis('off')
        axes[j].set_facecolor('#0f0f0f')

    plt.suptitle("2026 FIFA World Cup — Group Stage Team Assignment",
                 fontsize=20, fontweight='bold', color='white', y=0.995)
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()


visualize_groups_flags(wc_team)

# %%
# define a function to predict team winner each match
def find_stats(team_1):    
    past_games = team_df[team_df["team"] == team_1].sort_values("date")
    last5 = past_games.tail(5)

    if len(past_games) == 0:
        print(f"WARNING: No data found for '{team_1}'")
        return [100, 1.0, 1.0, 1.0, 1.0, 50, 50, 1.0, 1.0]  # neutral rank=100, not 0

    team_1_rank = past_games["rank"].values[-1]
    team_1_goals = past_games.score.mean()
    team_1_goals_l5 = last5.score.mean()
    team_1_goals_suf = past_games.suf_score.mean()
    team_1_goals_suf_l5 = last5.suf_score.mean()
    team_1_rank_suf = past_games.suf_rank.mean()
    team_1_rank_suf_l5 = last5.suf_rank.mean()
    team_1_gp_rank = past_games.points_by_rank.mean()
    team_1_gp_rank_l5 = last5.points_by_rank.mean()

    return [team_1_rank, team_1_goals, team_1_goals_l5, team_1_goals_suf, 
            team_1_goals_suf_l5, team_1_rank_suf, team_1_rank_suf_l5, team_1_gp_rank, team_1_gp_rank_l5]

def find_features(team_1, team_2):
    rank_dif = team_1[0] - team_2[0]
    goals_dif = team_1[1] - team_2[1]
    goals_dif_l5 = team_1[2] - team_2[2]
    goals_suf_dif = team_1[3] - team_2[3]
    goals_suf_dif_l5 = team_1[4] - team_2[4]
    goals_per_ranking_dif = (team_1[1]/team_1[5]) - (team_2[1]/team_2[5])
    dif_rank_agst = team_1[5] - team_2[5]
    dif_rank_agst_l5 = team_1[6] - team_2[6]
    dif_gp_rank = team_1[7] - team_2[7]
    dif_gp_rank_l5 = team_1[8] - team_2[8]
    
    return [rank_dif, goals_dif, goals_dif_l5, goals_suf_dif, goals_suf_dif_l5, goals_per_ranking_dif, 
            dif_rank_agst, dif_rank_agst_l5, dif_gp_rank, dif_gp_rank_l5, 1, 0]

def get_win_prob(team1, team2):
    s1 = find_stats(team1)
    s2 = find_stats(team2)
    if s1 is None or s2 is None:
        return 0.5, 0.5
    
    f1 = find_features(s1, s2)
    f2 = find_features(s2, s1)

    p1 = best_xgb.predict_proba([f1])
    p2 = best_xgb.predict_proba([f2])

    t1 = (p1[0][0] + p2[0][1]) / 2
    t2 = (p2[0][0] + p1[0][1]) / 2

    total = t1 + t2
    
    return round(t1 / total, 2), round(t2 / total, 2)

# %%
advanced_group = []
group_results = {}
group_standings = {}

for group, teams in groups.items():

    # team : [points, probabilities]
    table = {team: [0, []] for team in teams}
    group_results[group] = []

    # Play every fixture
    for team1, team2 in combinations(teams, 2):

        p1, p2 = get_win_prob(team1, team2)

        # Award points
        if abs(p1 - p2) < 0.05:
            result = "Draw"
            table[team1][0] += 1
            table[team2][0] += 1

        elif p1 > p2:
            result = team1
            table[team1][0] += 3

        else:
            result = team2
            table[team2][0] += 3

        # Save probabilities
        table[team1][1].append(p1)
        table[team2][1].append(p2)

        # Save fixture
        group_results[group].append({
            "team1": team1,
            "team2": team2,
            "team1_prob": p1,
            "team2_prob": p2,
            "winner": result
        })

    # Build final standings
    final_table = [
        {
            "team": team,
            "points": points
        }
        for team, (points, _) in table.items()
    ]

    final_table.sort(key=lambda x: x["points"], reverse=True)

    # Save standings
    group_standings[group] = final_table

    # Save top 2
    advanced_group.append([
        final_table[0]["team"],
        final_table[1]["team"]
    ])

# %%
def bar(p, width=20):
    filled = int(p * width)
    return "█" * filled + "░" * (width - filled)

for group, matches in group_results.items():

    print(f"\n===== GROUP {group} =====")

    for m in matches:
        print(
            f"{m['team1']:<12}"
            f"{bar(m['team1_prob'])} "
            f"{m['team1_prob']:.1%}"
        )
        print(
            f"{m['team2']:<12}"
            f"{bar(m['team2_prob'])} "
            f"{m['team2_prob']:.1%}"
        )
        print(f"Winner: {m['winner']}\n")
# Out:
# ===== GROUP A =====
# Mexico      █████████████░░░░░░░ 67.0%
# South Africa██████░░░░░░░░░░░░░░ 33.0%
# Winner: Mexico
#
# Mexico      ███████████░░░░░░░░░ 55.0%
# South Korea █████████░░░░░░░░░░░ 45.0%
# Winner: Mexico
#
# Mexico      ███████████░░░░░░░░░ 56.0%
# Czech Republic████████░░░░░░░░░░░░ 44.0%
# Winner: Mexico
#
# South Africa███████░░░░░░░░░░░░░ 38.0%
# South Korea ████████████░░░░░░░░ 62.0%
# Winner: South Korea
#
# South Africa█████████░░░░░░░░░░░ 45.0%
# Czech Republic███████████░░░░░░░░░ 55.0%
# Winner: Czech Republic
#
# South Korea ██████████░░░░░░░░░░ 53.0%
# Czech Republic█████████░░░░░░░░░░░ 47.0%
# Winner: South Korea
#
#
# ===== GROUP B =====
# Switzerland ███████████░░░░░░░░░ 55.0%
# Canada      █████████░░░░░░░░░░░ 45.0%
# Winner: Switzerland
#
# Switzerland ██████████████░░░░░░ 71.0%
# Bosnia and Herzegovina█████░░░░░░░░░░░░░░░ 29.0%
# Winner: Switzerland
#
# Switzerland █████████████░░░░░░░ 67.0%
# Qatar       ██████░░░░░░░░░░░░░░ 33.0%
# ...

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 6, figsize=(24, 8), sharey=True)

axes = axes.flatten()   # Make indexing easier

for ax, (group, standings) in zip(axes, group_standings.items()):

    teams = [team["team"] for team in standings]
    points = [team["points"] for team in standings]

    bars = ax.bar(teams, points)

    ax.set_title(f"Group {group}", fontsize=12)
    ax.set_ylim(0, 9)
    ax.grid(axis="y", alpha=0.3)

    # Rotate team names
    ax.tick_params(axis="x", rotation=45)

    # Show points on bars
    for bar, point in zip(bars, points):
        ax.text(
            bar.get_x() + bar.get_width() / 2,
            point + 0.1,
            str(point),
            ha="center",
            va="bottom",
            fontsize=9
        )

# Hide any unused axes (if fewer than 12 groups)
for ax in axes[len(group_standings):]:
    ax.set_visible(False)

fig.suptitle("2026 FIFA World Cup Group Stage Standings", fontsize=18)
fig.tight_layout(rect=[0, 0, 1, 0.95])

plt.show()

# %%
group_letters = list(group_standings.keys())

# Top 2 teams
first_place = {
    group: standings[0]["team"]
    for group, standings in group_standings.items()
}

second_place = {
    group: standings[1]["team"]
    for group, standings in group_standings.items()
}

# All third-place teams
third_place = [
    {
        "group": group,
        "team": standings[2]["team"],
        "points": standings[2]["points"]
    }
    for group, standings in group_standings.items()
]

# Best 8 third-place teams
third_place_sorted = sorted(
    third_place,
    key=lambda x: x["points"],
    reverse=True
)

best_third_place = {
    team["group"]: team["team"]
    for team in third_place_sorted[:8]
}

print('Best 8 third place teams qualified for the Knockout stage:\n')

for idx, (group, team) in enumerate(best_third_place.items(), start=1):
    print(f"Top {idx}: Group {group} - {team}")

best_third_place
# Out:
# Best 8 third place teams qualified for the Knockout stage:
#
# Top 1: Group E - Ecuador
# Top 2: Group G - Iran
# Top 3: Group A - Czech Republic
# Top 4: Group B - Qatar
# Top 5: Group C - Scotland
# Top 6: Group D - Australia
# Top 7: Group H - Saudi Arabia
# Top 8: Group I - Norway
# {'E': 'Ecuador',
#  'G': 'Iran',
#  'A': 'Czech Republic',
#  'B': 'Qatar',
#  'C': 'Scotland',
#  'D': 'Australia',
#  'H': 'Saudi Arabia',
#  'I': 'Norway'}

# %% [markdown]
# ## 3.2 Knockout Stage

# %%
matches = {
    # R32 leaves (left half)
    74: ('1E', '3ABCDF', None, None),
    77: ('1I', '3CDFGH', None, None),
    73: ('2A', '2B',     None, None),
    75: ('1F', '2C',     None, None),
    83: ('2K', '2L',     None, None),
    84: ('1H', '2J',     None, None),
    81: ('1D', '3BEFIJ', None, None),
    82: ('1G', '3AEHIJ', None, None),
    # R32 leaves (right half)
    76: ('1C', '2F',     None, None),
    78: ('2E', '2I',     None, None),
    79: ('1A', '3CEFHI', None, None),
    80: ('1L', '3EHIJK', None, None),
    86: ('1J', '2H',     None, None),
    88: ('2D', '2G',     None, None),
    85: ('1B', '3EFGIJ', None, None),
    87: ('1K', '3DEIJL', None, None),
    # R16
    89: (None, None, 74, 77),
    90: (None, None, 73, 75),
    93: (None, None, 83, 84),
    94: (None, None, 81, 82),
    91: (None, None, 76, 78),
    92: (None, None, 79, 80),
    95: (None, None, 86, 88),
    96: (None, None, 85, 87),
    # QF
    97: (None, None, 89, 90),
    98: (None, None, 93, 94),
    99: (None, None, 91, 92),
    100: (None, None, 95, 96),
    # SF
    101: (None, None, 97, 98),
    102: (None, None, 99, 100),
    # Final & 3rd place
    104: (None, None, 101, 102),
    103: (None, None, 101, 102),  # losers bracket, handled separately
}

leaves_left = [74, 77, 73, 75, 83, 84, 81, 82]
leaves_right = [76, 78, 79, 80, 86, 88, 85, 87]

# ============================================================
# POSITION CALCULATION
# ============================================================
x_left = {74: 0, 77: 0, 73: 0, 75: 0, 83: 0, 84: 0, 81: 0, 82: 0,
          89: 1, 90: 1, 93: 1, 94: 1,
          97: 2, 98: 2,
          101: 3}
x_right = {76: 8, 78: 8, 79: 8, 80: 8, 86: 8, 88: 8, 85: 8, 87: 8,
           91: 7, 92: 7, 95: 7, 96: 7,
           99: 6, 100: 6,
           102: 5}
x_pos = {**x_left, **x_right, 104: 4, 103: 4}

y_pos = {}
for i, m in enumerate(leaves_left):
    y_pos[m] = 7 - i
for i, m in enumerate(leaves_right):
    y_pos[m] = 7 - i

def compute_y(m):
    if m in y_pos:
        return y_pos[m]
    _, _, c1, c2 = matches[m]
    y = (compute_y(c1) + compute_y(c2)) / 2
    y_pos[m] = y
    return y

for m in [89, 90, 93, 94, 91, 92, 95, 96, 97, 98, 99, 100, 101, 102]:
    compute_y(m)
y_pos[104] = (y_pos[101] + y_pos[102]) / 2
y_pos[103] = y_pos[104] - 1.2  # place 3rd place match below the final

# ============================================================
# DRAW
# ============================================================
fig, ax = plt.subplots(figsize=(18, 12))
ax.set_xlim(-0.5, 8.5)
ax.set_ylim(-2, 8)
ax.axis('off')

box_w, box_h = 0.7, 0.55

def draw_box(m, label_override=None):
    x, y = x_pos[m], y_pos[m]
    t1, t2, c1, c2 = matches[m]
    if c1 is not None:
        t1, t2 = f"W{c1}", f"W{c2}"
    if m == 103:
        t1, t2 = f"L101", f"L102"

    rect = patches.FancyBboxPatch((x - box_w/2, y - box_h/2), box_w, box_h,
                                    boxstyle="round,pad=0.02", linewidth=1,
                                    edgecolor='#888888', facecolor='#e9e9e9')
    ax.add_patch(rect)
    ax.text(x, y + 0.13, t1, fontsize=8.5, ha='center', va='center', fontweight='bold')
    ax.text(x, y - 0.13, t2, fontsize=8.5, ha='center', va='center', fontweight='bold')
    ax.text(x, y - box_h/2 - 0.18, f"({m})", fontsize=8, ha='center', va='center', color='gray')

def draw_connector(child, parent, is_right=False):
    xc, yc = x_pos[child], y_pos[child]
    xp, yp = x_pos[parent], y_pos[parent]
    xmid = (xc + xp) / 2
    ax.plot([xc + (box_w/2 if not is_right else -box_w/2), xmid], [yc, yc], color='#aaaaaa', lw=1)
    ax.plot([xmid, xmid], [yc, yp], color='#aaaaaa', lw=1)
    ax.plot([xmid, xp - (box_w/2 if not is_right else -box_w/2)], [yp, yp], color='#aaaaaa', lw=1)

# Draw all boxes
for m in matches:
    draw_box(m)

# Draw connectors (left side: child.x < parent.x)
left_pairs = [(74,89),(77,89),(73,90),(75,90),(83,93),(84,93),(81,94),(82,94),
              (89,97),(90,97),(93,98),(94,98),(97,101),(98,101)]
for c, p in left_pairs:
    draw_connector(c, p, is_right=False)

# Draw connectors (right side: child.x > parent.x)
right_pairs = [(76,91),(78,91),(79,92),(80,92),(86,95),(88,95),(85,96),(87,96),
               (91,99),(92,99),(95,100),(96,100),(99,102),(100,102)]
for c, p in right_pairs:
    draw_connector(c, p, is_right=True)

# Final + 3rd place connectors
draw_connector(101, 104, is_right=False)
draw_connector(102, 104, is_right=True)
ax.plot([x_pos[101], x_pos[101]], [y_pos[101]-box_h/2, y_pos[103]], color='#aaaaaa', lw=1)
ax.plot([x_pos[101], x_pos[103]], [y_pos[103], y_pos[103]], color='#aaaaaa', lw=1)
ax.plot([x_pos[102], x_pos[102]], [y_pos[102]-box_h/2, y_pos[103]], color='#aaaaaa', lw=1)
ax.plot([x_pos[103], x_pos[102]], [y_pos[103], y_pos[103]], color='#aaaaaa', lw=1)

# Round labels
round_labels = {0: 'ROUND OF 32', 1: 'ROUND OF 16', 2: 'QUARTERFINALS', 3: 'SEMIFINALS',
                4: 'FINAL', 5: 'SEMIFINALS', 6: 'QUARTERFINALS', 7: 'ROUND OF 16', 8: 'ROUND OF 32'}
for xr, label in round_labels.items():
    ax.text(xr, 7.8, label, fontsize=9, ha='center', fontweight='bold', color='#444444')
ax.text(4, y_pos[103] - 0.5, 'THIRD PLACE MATCH', fontsize=8, ha='center', color='#444444')

plt.suptitle("FIFA WORLD CUP 2026 — Knockout Bracket", fontsize=18, fontweight='bold', y=0.98)
plt.tight_layout()
plt.show()

# %%
round_of_32 = [
    ("Match_73", second_place['A'], second_place['B']),     # 2A vs 2B
    ("Match_74", first_place['E'],  best_third_place['D']), # 1E vs 3ABCDF
    ("Match_75", first_place['F'],  second_place['C']),     # 1F vs 2C
    ("Match_76", first_place['C'],  second_place['F']),     # 1C vs 2F
    ("Match_77", first_place['I'],  best_third_place['H']), # FIXED: 1I vs 3CDFGH
    ("Match_78", second_place['E'], second_place['I']),     # 2E vs 2I
    ("Match_79", first_place['A'],  best_third_place['C']), # 1A vs 3CEFHI
    ("Match_80", first_place['L'],  best_third_place['I']), # 1L vs 3EHIJK
    ("Match_81", first_place['D'],  best_third_place['B']), # 1D vs 3BEFIJ
    ("Match_82", first_place['G'],  best_third_place['A']), # 1G vs 3AEHIJ
    ("Match_83", second_place['K'], second_place['L']),     # 2K vs 2L
    ("Match_84", first_place['H'],  second_place['J']),     # 1H vs 2J
    ("Match_85", first_place['B'],  best_third_place['G']), # 1B vs 3EFGIJ
    ("Match_86", first_place['J'],  second_place['H']),     # 1J vs 2H
    ("Match_87", first_place['K'],  best_third_place['E']), # 1K vs 3DEIJL
    ("Match_88", second_place['D'], second_place['G']),     # 2D vs 2G
]

ROUND_OF_16_STRUCTURE = [
    ("Match_89", "Match_74", "Match_77"),     
    ("Match_90", "Match_73", "Match_75"),
    ("Match_91", "Match_83", "Match_84"), 
    ("Match_92", "Match_81", "Match_82"),   
    ("Match_93", "Match_79", "Match_80"), 
    ("Match_94", "Match_76", "Match_78"),   
    ("Match_95", "Match_85", "Match_86"), 
    ("Match_96", "Match_87", "Match_88"),
]

QUARTERFINALS_STRUCTURE = [
    ("Match_97", "Match_89", "Match_90"),     
    ("Match_98", "Match_91", "Match_92"),
    ("Match_99", "Match_93", "Match_94"), 
    ("Match_100", "Match_95", "Match_96")
]

SEMIFINALS_STRUCTURE = [
    ("Match_101", "Match_97", "Match_98"),     
    ("Match_102", "Match_99", "Match_100")
]

playoffs = {"R32": [], "R16": [], "QF": [], "SF": [], "Final": []}
all_tournament_results = {}

def simulate_bracket_stage(stage_name: str, stage_structure: list, previous_winners: dict):
    """Simulates a stage of the bracket using team predictions."""
    print(f"\n==========================================")
    print(f"      {stage_name.upper()}")
    print(f"==========================================")

    current_winners = {}
    current_losers = {}
    stage_match_tuples = []

    for next_match_id, feeder1_id, feeder2_id in stage_structure:
        team1 = previous_winners[feeder1_id]
        team2 = previous_winners[feeder2_id]

        prob1, prob2 = get_win_prob(team1, team2)
        stage_match_tuples.append((team1, team2, (prob1, prob2)))

        if prob1 >= prob2:
            winner, winner_prob = team1, prob1
            loser = team2
        else:
            winner, winner_prob = team2, prob2
            loser = team1

        current_winners[next_match_id] = winner
        current_losers[f"{next_match_id}_loser"] = loser

        print(
            f"{next_match_id}: {team1} ({prob1*100:.0f}%) vs {team2} ({prob2*100:.0f}%) "
            f"--> Winner: {winner} ({winner_prob*100:.0f}%)"
        )

    return current_winners, current_losers, stage_match_tuples

# Round of 32
r32_winners = {}
for match_id, team1, team2 in round_of_32:
    prob1, prob2 = get_win_prob(team1, team2)
    playoffs["R32"].append((team1, team2, (prob1, prob2)))
    winner = team1 if prob1 >= prob2 else team2
    r32_winners[match_id] = winner

all_tournament_results.update(r32_winners)

# Round of 16
r16_winners, _, playoffs["R16"] = simulate_bracket_stage(
    "Round of 16", ROUND_OF_16_STRUCTURE, all_tournament_results
)
all_tournament_results.update(r16_winners)

# Quarterfinals
qf_winners, _, playoffs["QF"] = simulate_bracket_stage(
    "Quarterfinals", QUARTERFINALS_STRUCTURE, all_tournament_results
)
all_tournament_results.update(qf_winners)

# Semifinals
sf_winners, sf_losers, playoffs["SF"] = simulate_bracket_stage(
    "Semifinals", SEMIFINALS_STRUCTURE, all_tournament_results
)
all_tournament_results.update(sf_winners)
all_tournament_results.update(sf_losers)  # Populates 'Match_101_loser' and 'Match_102_loser'

# Third Place Play-off
match_103_team1 = all_tournament_results["Match_101_loser"]
match_103_team2 = all_tournament_results["Match_102_loser"]
p1, p2 = get_win_prob(match_103_team1, match_103_team2)
third_place_winner = match_103_team1 if p1 >= p2 else match_103_team2

print(
    f"\n3rd Place Match: {match_103_team1} ({p1*100:.0f}%) vs {match_103_team2} ({p2*100:.0f}%) "
    f"--> 3rd Place: {third_place_winner}"
)

# Final 
final_team1 = all_tournament_results["Match_101"]
final_team2 = all_tournament_results["Match_102"]
p1, p2 = get_win_prob(final_team1, final_team2)
champion = final_team1 if p1 >= p2 else final_team2
playoffs["Final"] = [(final_team1, final_team2, (p1, p2))]

print(
    f"\nWorld Cup Final (Match 104): {final_team1} ({p1*100:.0f}%) vs {final_team2} ({p2*100:.0f}%)\n"
)
print(f"🏆 World Cup 2026 Champion: {champion}")
# Out:
# ...
#       ROUND OF 16
# ...
# Match_89: Germany (46%) vs France (54%) --> Winner: France (54%)
# Match_90: South Korea (39%) vs Morocco (61%) --> Winner: Morocco (61%)
# Match_91: Croatia (44%) vs Spain (56%) --> Winner: Spain (56%)
# Match_92: United States (43%) vs Belgium (57%) --> Winner: Belgium (57%)
# Match_93: Mexico (46%) vs England (54%) --> Winner: England (54%)
# Match_94: Brazil (53%) vs Senegal (47%) --> Winner: Brazil (53%)
# Match_95: Switzerland (41%) vs Argentina (59%) --> Winner: Argentina (59%)
# Match_96: Portugal (60%) vs Turkey (40%) --> Winner: Portugal (60%)
#
# ...
#       QUARTERFINALS
# ...
# Match_97: France (55%) vs Morocco (45%) --> Winner: France (55%)
# Match_98: Spain (55%) vs Belgium (45%) --> Winner: Spain (55%)
# Match_99: England (51%) vs Brazil (49%) --> Winner: England (51%)
# Match_100: Argentina (53%) vs Portugal (47%) --> Winner: Argentina (53%)
#
# ...
#       SEMIFINALS
# ...
# Match_101: France (49%) vs Spain (51%) --> Winner: Spain (51%)
# ...

# %% [markdown]
# ## 3.3 Plotting Predictions from Group Stage to Final

# %%
stage_colors = {
    "R32": "#3B82F6",  # Blue
    "R16": "#10B981",  # Green
    "QF": "#F59E0B",  # Amber/Yellow
    "SF": "#EF4444",  # Red
    "Final": "#A855F7",  # Purple
}

round_y = {
    "R32": [i * 2.5 for i in range(16)],
    "R16": [i * 5 + 1.25 for i in range(8)],
    "QF": [i * 10 + 3.75 for i in range(4)],
    "SF": [i * 20 + 8.75 for i in range(2)],
    "Final": [18.75],
}

round_x = {"R32": 0, "R16": 1, "QF": 2, "SF": 3, "Final": 4}

fig = go.Figure()

# 2. Plot matches with stage-based colors
for rnd, matches in playoffs.items():
    x = round_x[rnd]
    # Get the assigned color for the current round/stage
    current_color = stage_colors.get(rnd, "gray")

    for i, (team1, team2, probs) in enumerate(matches):
        y = round_y[rnd][i]
        p1, p2 = probs
        winner = team1 if p1 >= p2 else team2

        label = (
            f"<b>{winner}</b><br>" f"{team1}: {p1:.0%}<br>" f"{team2}: {p2:.0%}"
        )

        fig.add_trace(
            go.Scatter(
                x=[x],
                y=[y],
                mode="markers+text",
                marker=dict(
                    size=18,
                    color=current_color,  # <-- Applied stage color here
                    line=dict(color="white", width=1),
                ),
                text=[label],
                textposition="middle right",
                hovertemplate=(
                    f"<b>{rnd}</b><br>"
                    f"{team1}: {p1:.1%}<br>"
                    f"{team2}: {p2:.1%}<extra></extra>"
                ),
                showlegend=False,
            )
        )

# 3. Draw connector lines
rounds = ["R32", "R16", "QF", "SF", "Final"]
for r in range(len(rounds) - 1):
    curr_round = rounds[r]
    next_round = rounds[r + 1]

    curr_y = round_y[curr_round]
    next_y = round_y[next_round]

    x0 = round_x[curr_round]
    x1 = round_x[next_round]

    group_size = 2

    for i in range(len(next_y)):
        y_top = curr_y[i * group_size]
        y_bot = curr_y[i * group_size + 1]
        y_mid = next_y[i]

        fig.add_shape(
            type="line",
            x0=x0,
            y0=y_top,
            x1=x0 + 0.45,
            y1=y_top,
            line=dict(color="lightgray", width=1),
        )
        fig.add_shape(
            type="line",
            x0=x0,
            y0=y_bot,
            x1=x0 + 0.45,
            y1=y_bot,
            line=dict(color="lightgray", width=1),
        )
        fig.add_shape(
            type="line",
            x0=x0 + 0.45,
            y0=y_top,
            x1=x0 + 0.45,
            y1=y_bot,
            line=dict(color="lightgray", width=1),
        )
        fig.add_shape(
            type="line",
            x0=x0 + 0.45,
            y0=y_mid,
            x1=x1,
            y1=y_mid,
            line=dict(color="lightgray", width=1),
        )

# 4. Add Stage Header Annotations with matching stage colors
for rnd, x in round_x.items():
    fig.add_annotation(
        x=x,
        y=max(round_y["R32"]) + 4,
        text=f"<b>{rnd}</b>",
        showarrow=False,
        font=dict(size=18, color=stage_colors.get(rnd, "white")),
    )

fig.update_layout(
    title={"text": "World Cup Knockout Stage Prediction", "x": 0.5},
    template="plotly_dark",
    width=1600,
    height=1000,
    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
    margin=dict(l=50, r=250, t=80, b=50),
)

fig.show()

# %% [markdown]
# # Part 4: Monte Carlo Simulation

# %% [markdown]
# **Utilizing Elgo Rating Formula to run Monte Carlo simulation (1,000 trials) on Model predict 8 quarter final teams**
#
# - Definition: According to Wikipedia: " The Elo[a] rating system is a method for calculating the relative skill levels of players, originally designed for rating chess players. It is a special case of the Bradley–Terry model. The Elo system was invented as an improved chess rating system over the previously used Harkness rating system[1] and has since been adapted for use in other zero-sum games and sports, including tennis, association football (soccer), American football, baseball, basketball, pool, various board games and esports. It is named after its creator Arpad Elo, a Hungarian-American chess master and physics professor."
#
# - Formula:
# ![image.png](attachment:image.png)
#
# - Source: https://en.wikipedia.org/wiki/Elo_rating_system

# %%
# extract the points for 2026 world cup teams
rank_df = pd.read_csv('data/fifa_ranking_2026-06-08.csv')
rank_df['team'] = rank_df['team'].replace(name_map)
wc_team = rank_df[rank_df['team'].isin(team_2026_list)]
wc_team.reset_index(drop=True, inplace=True)

# %%
# BASE PROBABILITY: Elo-style logistic transform of FIFA points

random.seed(42)

base_points = dict(zip(wc_team['team'], wc_team['points']))

def get_model_probabilities(team1, team2):
    p1_points = base_points[team1]
    p2_points = base_points[team2]
    p1 = 1 / (1 + 10 ** ((p2_points - p1_points) / 400))
    return (p1, 1 - p1)

# ============================================================
# MONTE CARLO SIMULATION
# ============================================================
N_SIM = 1000
champions = []

for _ in range(N_SIM):
    current_round = playoffs['QF']

    while True:
        winners = []
        for team1, team2, _ in current_round:
            p1, p2 = get_model_probabilities(team1, team2)
            winner = random.choices([team1, team2], weights=[p1, p2])[0]
            winners.append(winner)

        if len(winners) == 1:
            champions.append(winners[0])
            break

        next_round = []
        for i in range(0, len(winners), 2):
            t1 = winners[i]
            t2 = winners[i + 1]
            prob_t1, prob_t2 = get_model_probabilities(t1, t2)
            next_round.append((t1, t2, (prob_t1, prob_t2)))
        current_round = next_round

# ============================================================
# RESULTS
# ============================================================
champ_counts = Counter(champions)
champ_probs = pd.DataFrame(champ_counts.items(), columns=["Team", "Winning prob (%)"])
champ_probs["Winning prob (%)"] = (champ_probs["Winning prob (%)"] / N_SIM * 100).round(2)
champ_probs = champ_probs.sort_values("Winning prob (%)", ascending=False).reset_index(drop=True)

print("\n=== WORLD CUP 2026 SIMULATION RESULTS ===")
champ_probs
# Out:
# === WORLD CUP 2026 SIMULATION RESULTS ===
#         Team  Winning prob (%)
# 0      Spain              21.6
# 1  Argentina              21.1
# 2     France              18.5
# 3    England              15.8
# 4     Brazil               7.3
# 5   Portugal               6.5
# 6    Belgium               4.7
# 7    Morocco               4.5

# %%
plot_df = champ_probs.sort_values(by="Winning prob (%)")
n = len(plot_df)

colors = (["#9CA3AF"] * max(0, n - 4) + ["#3B82F6"] * min(3, max(0, n - 1)) + ["#10B981"])

ax = plot_df.set_index("Team")["Winning prob (%)"].plot(kind="barh", color=colors, figsize=(9, 5) )

for p in ax.patches:
  width = p.get_width()
  ax.annotate(f" {width:.2f}%", (width, p.get_y() + p.get_height() / 2), va="center")

plt.title("World Cup 2026 Champion Prediction (Probabilities of championship based on Mote Carlo simulation)", fontsize=12)
plt.xlim(0, max(plot_df["Winning prob (%)"]) * 1.15)
plt.show()

# %% [markdown]
# # Conclusion
# The Monte Carlo simulation identifies Spain (21.60%), Argentina (21.10%), France (18.50%), and England (15.80%) as the strongest championship contenders for the 2026 FIFA World Cup. The narrow probability gap among the leading teams highlights the competitiveness and uncertainty of the tournament. While the model favours these teams based on simulated outcomes, knockout football remains highly unpredictable due to single-match elimination and potential upsets.

# %% [markdown]
# <div align="center">
#   <div style="
#     background: linear-gradient(135deg, #16162a 0%, #1e1e38 100%);
#     border: 2px solid #ffd700;
#     border-radius: 20px;
#     padding: 30px 25px;
#     max-width: 400px;
#     box-shadow: 0 15px 35px rgba(0, 0, 0, 0.5);
#     font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, Roboto, sans-serif;
#     color: #ffffff;
#     margin: 25px auto;
#   ">
#     <div style="font-size: 50px; margin-bottom: 20px; text-shadow: 0 0 15px rgba(255, 215, 0, 0.3);">🏆 World Cup 2026</div>
#     <div style="font-size: 20px; margin-bottom: 20px; text-shadow: 0 0 15px rgba(255, 215, 0, 0.3);">Top 4 Potential Championships</div>
#     <div style="display: flex; flex-direction: column; gap: 12px; text-align: left;">
#         <div style="background: rgba(255, 215, 0, 0.1); border: 1px solid rgba(255, 215, 0, 0.3); padding: 12px 16px; border-radius: 12px; display: flex; justify-content: space-between; align-items: center;">
#           <div style="display: inline-flex; align-items: center; gap: 130px;">
#               <span style="font-weight: bold; color: #ffd700;">🥇 1st</span>
#               <span style="font-weight: 600; font-size: 1.1em;">Spain</span>
#           </div>
#         </div>
#         <div style="background: rgba(255, 255, 255, 0.05); border: 1px solid rgba(255, 255, 255, 0.1); padding: 12px 16px; border-radius: 12px; display: flex; justify-content: space-between; align-items: center;">
#           <div style="display: inline-flex; align-items: center; gap: 125px;">
#             <span style="font-weight: bold; color: #c0c0c0;">🥈 2nd</span>
#             <span style="font-weight: 500;">Argentina</span>
#           </div>
#         </div>
#         <div style="background: rgba(255, 255, 255, 0.05); border: 1px solid rgba(255, 255, 255, 0.1); padding: 12px 16px; border-radius: 12px; display: flex; justify-content: space-between; align-items: center;">
#           <div style="display: inline-flex; align-items: center; gap: 130px;">
#             <span style="font-weight: bold; color: #cd7f32;">🥉 3rd</span>
#             <span style="font-weight: 500;">France</span>
#           </div>
#         </div>
#         <div style="background: rgba(255, 255, 255, 0.02); border: 1px solid rgba(255, 255, 255, 0.05); padding: 12px 16px; border-radius: 12px; display: flex; justify-content: space-between; align-items: center;">
#           <div style="display: inline-flex; align-items: center; gap: 115px;">
#             <span style="font-weight: bold; color: #a0a0b8;">🔘 04th</span>
#             <span style="font-weight: 500; color: #a0a0b8;">England</span>
#           </div>
#         </div>
#       </div>
#   </div>
# </div>
